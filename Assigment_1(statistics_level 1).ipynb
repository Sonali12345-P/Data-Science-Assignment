# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
DataFrame = pd.read_csv('/content/sales_data_with_discounts.csv')
DataFrame
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# 1        10100             101000          11.560498     11676.102961
# 2        16100             112700           9.456886     10657.910157
# 3        20100             120600           6.935385      8364.074702
# 4         8100              24300          17.995663      4372.946230
# ..         ...                ...                ...              ...
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 0      160346.501180
# 1       89323.897039
# 2      102042.089843
# 3      112235.925298
# 4       19927.053770
# ..               ...
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# 448      4742.798174
# 449      2624.667705
#
# [450 rows x 13 columns]

# %%
DataFrame1 = DataFrame.select_dtypes(include=['number'])
DataFrame1
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 0      160346.501180
# 1       89323.897039
# 2      102042.089843
# 3      112235.925298
# 4       19927.053770
# ..               ...
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# 448      4742.798174
# 449      2624.667705
#
# [450 rows x 6 columns]

# %%
DataFrame = DataFrame.rename(columns={'Avg Price': 'AvgPrice', 'Total Sales Value': 'Totalsales', 'Discount Rate (%)':'Discountrate', 'Discount Amount':'DiscountAmount','Net Sales Value':'NetSaleValue'})

# %%
DataFrame
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      AvgPrice  Totalsales  Discountrate  DiscountAmount   NetSaleValue
# 0       12100      181500     11.654820    21153.498820  160346.501180
# 1       10100      101000     11.560498    11676.102961   89323.897039
# 2       16100      112700      9.456886    10657.910157  102042.089843
# 3       20100      120600      6.935385     8364.074702  112235.925298
# 4        8100       24300     17.995663     4372.946230   19927.053770
# ..        ...         ...           ...             ...            ...
# 445      1300        2600     15.475687      402.367873    2197.632127
# 446      2600       15600     17.057027     2660.896242   12939.103758
# 447      1600        3200     18.965550      606.897606    2593.102394
# 448      1900        5700     16.793014      957.201826    4742.798174
# 449      3100        3100     15.333300      475.332295    2624.667705
#
# [450 rows x 13 columns]

# %%
DataFrame1.mean()
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
DataFrame1.median()
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
DataFrame1.mode().iloc[0]
# Out:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64

# %%
DataFrame1.std()
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
DataFrame1.hist()
plt.tight_layout()
plt.show()

# %%
DataFrame1.boxplot()
plt.tight_layout()

# %%
plt.subplot(2,3,1)
sns.boxplot(x='Volume', data=DataFrame)


plt.subplot(2,3,2)
sns.boxplot(x='AvgPrice', data=DataFrame)

plt.subplot(2,3,3)
sns.boxplot(x='Totalsales', data=DataFrame)

plt.subplot(2,3,4)
sns.boxplot(x='Discountrate', data=DataFrame)

plt.subplot(2,3,5)
sns.boxplot(x='DiscountAmount', data=DataFrame)

plt.subplot(2,3,6)
sns.boxplot(x='NetSaleValue', data=DataFrame)
plt.tight_layout()

# %%
data= DataFrame.iloc[:, [0,1,2,3,5,6,7]]
data
# Out:
#            Date       Day  SKU City         BU  Brand       Model
# 0    01-04-2021  Thursday  M01    C    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C  Lifestyle  Jeera     M-Shoes
#
# [450 rows x 7 columns]

# %%
plt.figure(figsize=(8, 5))
DataFrame['Date'].value_counts().plot(kind='bar', color='violet')
plt.title('Bar Chart of Date')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
DataFrame['Day'].value_counts().plot(kind='bar', color='violet')
plt.title('Bar Chart of Day')
plt.xlabel('Day')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
DataFrame['SKU'].value_counts().plot(kind='bar', color='violet')
plt.title('Bar Chart of SKU')
plt.xlabel('SKU')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(3, 5))
DataFrame['City'].value_counts().plot(kind='bar', color='violet')
plt.title('Bar Chart of City')
plt.xlabel('City')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
DataFrame['BU'].value_counts().plot(kind='bar', color='violet')
plt.title('Bar Chart of BU')
plt.xlabel('BU')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
DataFrame['Brand'].value_counts().plot(kind='bar', color='violet')
plt.title('Bar Chart of Brand')
plt.xlabel('Brand')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
DataFrame['Model'].value_counts().plot(kind='bar', color='violet')
plt.title('Bar Chart of Model')
plt.xlabel('Model')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Analysis for Brand
#
# The bar chart of Brand shows the frequency of transactions for each brand. It reveals that RealU is the most popular brand, followed by other brands. This information can be valuable for analyzing the market share of different brands.

# %%
# Displaying summary statistics before standardization
print("Summary Statistics Before Standardization:")
print(DataFrame.describe())
# Out:
# Summary Statistics Before Standardization:
#            Volume      AvgPrice     Totalsales  Discountrate  DiscountAmount  \
# count  450.000000    450.000000     450.000000    450.000000      450.000000
# mean     5.066667  10453.433333   33812.835556     15.155242     3346.499424
# std      4.231602  18079.904840   50535.074173      4.220602     4509.902963
# min      1.000000    290.000000     400.000000      5.007822       69.177942
# 25%      3.000000    465.000000    2700.000000     13.965063      460.459304
# 50%      4.000000   1450.000000    5700.000000     16.577766      988.933733
# 75%      6.000000  10100.000000   53200.000000     18.114718     5316.495427
# max     31.000000  60100.000000  196400.000000     19.992407    25738.022194
#
#         NetSaleValue
# count     450.000000
# mean    30466.336131
# std     46358.656624
# min       326.974801
# 25%      2202.208645
# 50%      4677.788059
# 75%     47847.912852
# max    179507.479049

# %%
from sklearn.preprocessing import StandardScaler

# Selecting numerical columns for standardization
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
numerical_columns
# Out:
# ['Volume',
#  'Avg Price',
#  'Total Sales Value',
#  'Discount Rate (%)',
#  'Discount Amount',
#  'Net Sales Value']

# %%
# Standardizing numerical columns
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
# Creating a copy of the original dataset
sales_data_standardized = DataFrame1.copy()
sales_data_standardized[numerical_columns] = scaler.fit_transform(DataFrame1[numerical_columns])
sales_data_standardized[numerical_columns]
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value
# 0           3.952816         2.804756
# 1           1.849014         1.271026
# 2           1.622995         1.545675
# 3           1.113807         1.765810
# 4           0.227852        -0.227595
# ..               ...              ...
# 445        -0.653541        -0.610461
# 446        -0.152191        -0.378500
# 447        -0.608140        -0.601921
# 448        -0.530379        -0.555499
# 449        -0.637345        -0.601239
#
# [450 rows x 6 columns]

# %%
# Displaying summary statistics after standardization
print("\nSummary Statistics After Standardization:")
print(sales_data_standardized.describe())
# Out:
# Summary Statistics After Standardization:
#              Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  4.500000e+02  4.500000e+02       4.500000e+02       4.500000e+02
# mean   6.118562e-17  3.157968e-17       1.578984e-17      -3.552714e-17
# std    1.001113e+00  1.001113e+00       1.001113e+00       1.001113e+00
# min   -9.620925e-01 -5.627654e-01      -6.619170e-01      -2.406935e+00
# 25%   -4.889322e-01 -5.530754e-01      -6.163534e-01      -2.823066e-01
# 50%   -2.523521e-01 -4.985344e-01      -5.569226e-01       3.374180e-01
# 75%    2.208081e-01 -1.957016e-02       3.840648e-01       7.019781e-01
# max    6.135311e+00  2.749009e+00       3.220894e+00       1.147360e+00
#
#        Discount Amount  Net Sales Value
# count     4.500000e+02     4.500000e+02
# mean     -5.526444e-17     1.973730e-17
# std       1.001113e+00     1.001113e+00
# min      -7.275032e-01    -6.508581e-01
# 25%      -6.406462e-01    -6.103625e-01
# 50%      -5.233349e-01    -5.569025e-01
# 75%       4.373018e-01     3.753543e-01
# max       4.970494e+00     3.218536e+00

# %%
# Displaying comparison of data distributions before and after standardization
for column in numerical_columns:
    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    plt.hist(DataFrame1[column], bins=20, color='violet', edgecolor='black')
    plt.title(f'Distribution of {column} (Before Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.subplot(1, 2, 2)
    plt.hist(sales_data_standardized[column], bins=20, color='salmon', edgecolor='black')
    plt.title(f'Distribution of {column} (After Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
# Displaying a portion of the dataset before one-hot encoding
print("Dataset Before One-Hot Encoding:")
print(DataFrame.head())
# Out:
# Dataset Before One-Hot Encoding:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    AvgPrice  Totalsales  Discountrate  DiscountAmount   NetSaleValue
# 0     12100      181500     11.654820    21153.498820  160346.501180
# 1     10100      101000     11.560498    11676.102961   89323.897039
# 2     16100      112700      9.456886    10657.910157  102042.089843
# 3     20100      120600      6.935385     8364.074702  112235.925298
# 4      8100       24300     17.995663     4372.946230   19927.053770

# %%
# Performing one-hot encoding on categorical columns
sales_data_encoded = pd.get_dummies(DataFrame)

# %%
# Displaying a portion of the transformed dataset after one-hot encoding
print("\nDataset After One-Hot Encoding:")
print(sales_data_encoded.head())
# Out:
# Dataset After One-Hot Encoding:
#    Volume  AvgPrice  Totalsales  Discountrate  DiscountAmount   NetSaleValue  \
# 0      15     12100      181500     11.654820    21153.498820  160346.501180
# 1      10     10100      101000     11.560498    11676.102961   89323.897039
# 2       7     16100      112700      9.456886    10657.910157  102042.089843
# 3       6     20100      120600      6.935385     8364.074702  112235.925298
# 4       3      8100       24300     17.995663     4372.946230   19927.053770
#
#    Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  Date_04-04-2021  ...  \
# 0             True            False            False            False  ...
# 1             True            False            False            False  ...
# 2             True            False            False            False  ...
# 3             True            False            False            False  ...
# 4             True            False            False            False  ...
#
#    Model_Vedic Cream  Model_Vedic Oil  Model_Vedic Shampoo  Model_W-Casuals  \
# 0              False            False                False            False
# 1              False            False                False            False
# 2              False            False                False            False
# 3              False            False                False            False
# 4              False            False                False            False
#
#    Model_W-Inners  Model_W-Lounge  Model_W-Western  Model_YM-98   Model_YM-99  \
# 0           False           False            False         False        False
# 1           False           False            False         False        False
# 2           False           False            False         False         True
# 3           False           False            False         False        False
# 4           False           False            False          True        False
#
#    Model_YM-99 Plus
# 0             False
# 1             False
# 2             False
# 3              True
# 4             False
#
# [5 rows x 101 columns]

# %% [markdown]
#  **Conclusion**
#
#
# Key Findings from Descriptive Analytics and Data Visualizations
# Numerical Columns:
#
# The mean Volume of sales is 5.07 units, with a median of 4 units, indicating a slightly right-skewed distribution.
# Total Sales Value has a mean of 33812.84 and a median of 5700, suggesting a right-skewed distribution with some transactions having considerably higher sales values.
# Discount Amount and Net Sales Value exhibit similar patterns, with a wide range of values and a right-skewed distribution.
# Data Visualization:
#
# Histograms and boxplots revealed the distribution and presence of outliers in numerical variables.
# Bar charts for categorical columns illustrated the frequency of transactions in each category, providing insights into the distribution of sales across different cities and brands.
# Reflection on the Importance of Data Preprocessing Steps
# Standardization:
#
# Standardizing numerical variables ensures that they are on the same scale, improving the performance of analytical models.
# By scaling the data to have a mean of 0 and a standard deviation of 1, standardization facilitates accurate pattern recognition in the data.
# One-Hot Encoding:
#
# One-hot encoding transforms categorical variables into a numerical format suitable for machine learning algorithms.
# This process enables models to interpret categorical data effectively and make accurate predictions based on the transformed dataset.
# In conclusion, data preprocessing steps like standardization and one-hot encoding are essential for ensuring the quality and usability of the dataset in data analysis and machine learning tasks. These steps enable us to extract meaningful insights, build accurate models, and make informed decisions based on the data.
